# %%
import pandas as pd
import matplotlib.pyplot as plt 

# Define the data
series1 = pd.Series([12, 24, 36, 48, 60, 72, 84])
series2 = pd.Series([2, 4, 3, 18, 60, 72, 84])

# Plot the data
plt.plot(
    series1,
    series2,
    color='green',          # Line color
    linestyle='dashed',     # Line style
    linewidth=3,            # Line thickness
    marker='o',             # Marker type
    markerfacecolor='blue', # Marker fill color
    markersize=12           # Marker size
)

# Add labels and title
plt.title("Line Plot of Series1 vs Series2")
plt.xlabel("Series1 Values")
plt.ylabel("Series2 Values")

# Add grid
plt.grid(True)

# Show plot
plt.show()

# %%
import pandas as pd

# Create DataFrame
df = pd.DataFrame({
    'Country': ['China', 'India', 'Indonesia', 'Pakistan'],
    'Population': [1420062022, 1368737513, 269536482, 204596442],
    'Area': [9388211, 2973190, 1811570, 770880]
})

# Display DataFrame
print(df)

# Access the 'Country' column
print("\nCountry column:")
print(df['Country'])

# Show column names
print("\nColumns:")
print(df.columns)

# Show index
print("\nIndex:")
print(df.index)
# Out:
#      Country  Population     Area
# 0      China  1420062022  9388211
# 1      India  1368737513  2973190
# 2  Indonesia   269536482  1811570
# 3   Pakistan   204596442   770880
#
# Country column:
# 0        China
# 1        India
# 2    Indonesia
# 3     Pakistan
# Name: Country, dtype: object
#
# Columns:
# Index(['Country', 'Population', 'Area'], dtype='object')
#
# Index:
# RangeIndex(start=0, stop=4, step=1)

# %%
import seaborn as sns
import pandas as pd

# Load Titanic dataset from seaborn
titanic_df = sns.load_dataset("titanic")

# Save it as CSV for later use
titanic_df.to_csv("titanic.csv", index=False)

print(titanic_df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import pandas as pd
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Number of rows
n = 10

# Generate random data
time_period = np.arange(2000, 2000 + n*5, 5)  # e.g., 2000, 2005, 2010,...
population = np.random.randint(1000000000, 1400000000, size=n)  # Random population
gdp = np.random.randint(400, 3000, size=n)  # Random GDP in billions

# Create DataFrame
data = pd.DataFrame({
    "Time period": time_period,
    "Population": population,
    "GDP": gdp
})

# Save to CSV
data.to_csv("CountryData.IND.csv", index=False)

# Show the first few rows
print(data)
# Out:
#    Time period  Population   GDP
# 0         2000  1199900595   530
# 1         2005  1325190492  2085
# 2         2010  1250975502  1169
# 3         2015  1127521863  2791
# 4         2020  1133224038  1915
# 5         2025  1304224377  2833
# 6         2030  1133120466  1615
# 7         2035  1249467210  1355
# 8         2040  1361846218  2724
# 9         2045  1359525748  1584

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('CountryData.IND.csv')

# Create histogram of "Time period" column
data['Time period'].hist(bins=10)

# Show the plot
plt.title("Histogram of Time Period")
plt.xlabel("Time period")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Number of data points
n = 1000

# Generate normally distributed data
# Mean = 50, Standard Deviation = 10
time_period = np.random.normal(loc=50, scale=10, size=n)

# Optional: create a DataFrame
data = pd.DataFrame({
    "Time period": time_period
})

# Plot histogram
plt.hist(data['Time period'], bins=30, color='skyblue', edgecolor='black')
plt.title("Histogram of Normally Distributed Time Period")
plt.xlabel("Time period")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Generate date range (like your example 2014-06 to 2018-08)
dates = pd.date_range(start='2014-06-01', end='2018-08-31', freq='B')  # 'B' = business days

# Initialize stock price
price = 200  # starting price
prices = []

# Generate stock prices using random walk
for _ in range(len(dates)):
    daily_return = np.random.normal(loc=0.0005, scale=0.02)  # small drift and daily volatility
    price *= (1 + daily_return)
    prices.append(price)

# Create DataFrame
df = pd.DataFrame({'Close': prices}, index=dates)

# Plot the simulated stock prices
df.plot(title="Stock Prices (Amazon)")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

series1 = pd.Series([12, 24, 36, 48, 60, 72, 84])
series2 = pd.Series([2, 4, 3, 18, 60, 72, 84])

plt.plot(series1, series2, color='green', 
         linewidth=2, markerfacecolor='blue')
plt.title("Series Comparison Plot")
plt.xlabel("Series 1 Values")
plt.ylabel("Series 2 Values")
plt.show()
